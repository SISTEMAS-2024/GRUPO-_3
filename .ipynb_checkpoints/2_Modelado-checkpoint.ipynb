# %% [markdown]
# ### Actividad Grupal: Análisis de Datos del Municipio de Monterrey (DATOS DEL 2015)
# ### INTEGRANTES GRUPO 3:
# #### •	ALDAZ RIVERA DANI ALEXANDER
# #### •	BONILLA VIMOS WASHINGTON RAMIRO
# ### Parte 4 : Modelado

# %%
# importa la libreria de pandas
# %matplotlib inline
import pandas as pd

# %%
# Ruta de la carpeta que contiene los archivos
df_2015 = pd.read_excel('C:/data/2015.xlsx', sheet_name='Sheet1')

# %%
# Asignamos el DataFrame el modelo
data = df_2015.copy()

# %%
# Información del DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10313 entries, 0 to 10312
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FECHA                       10313 non-null  datetime64[ns]
#  1   FACTURA                     10313 non-null  object
#  2   BENEFICIARIO                10313 non-null  object
#  3   RFC                         10313 non-null  object
#  4   CONCEPTO                    10313 non-null  object
#  5   IMPORTE                     10313 non-null  float64
#  6   FECHA DEL PAGO POR CADENAS  448 non-null    datetime64[ns]
#  7   FUENTE                      10313 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(5)
# memory usage: 644.7+ KB

# %%
data.head()
# Out:
#        FECHA FACTURA                                   BENEFICIARIO  \
# 0 2015-01-30      70                       CONSTCOMER, S.A. DE C.V.
# 1 2015-01-30      73                       CONSTCOMER, S.A. DE C.V.
# 2 2015-01-30      81                       CONSTCOMER, S.A. DE C.V.
# 3 2015-01-26      01  SRIA. DE FIN.Y TESORERIA GRAL.DEL EDO.DE N.L.
# 4 2015-01-30      25           IMPULSORA INDUSTRIAL MONTERREY ,S.A.
#
#               RFC                                        CONCEPTO     IMPORTE  \
# 0  CON-060323-F88             EQUIPAMIENTO  PARA PARQUES Y PLAZAS   2173840.0
# 1  CON-060323-F88             EQUIPAMIENTO  PARA PARQUES Y PLAZAS  12708960.0
# 2  CON-060323-F88             EQUIPAMIENTO  PARA PARQUES Y PLAZAS   4346102.4
# 3    GEN620601DTA  EX. DE CONTROL Y CONFIANZA PROG. SUBSEMUN 2014   4184000.0
# 4    IIM651101EVA                              MATERIAL ELECTRICO     11460.8
#
#   FECHA DEL PAGO POR CADENAS                               FUENTE
# 0                        NaT  OBRA PUBLICA Y RECURSOS ETIQUETADOS
# 1                        NaT  OBRA PUBLICA Y RECURSOS ETIQUETADOS
# 2                        NaT  OBRA PUBLICA Y RECURSOS ETIQUETADOS
# 3                        NaT  OBRA PUBLICA Y RECURSOS ETIQUETADOS
# 4                        NaT                          PROVEEDORES

# %%
# Llenar los valores faltantes del dataframe
for i, column in enumerate(list(str(d) for d in data.dtypes)):
    if column == "object":
        data[data.columns[i]] = data[data.columns[i]].fillna(data[data.columns[i]].mode())
        data[data.columns[i]] = data[data.columns[i]].astype("category").cat.codes
    else:
        data[data.columns[i]] = data[data.columns[i]].fillna(data[data.columns[i]].median())

# %%
data.head()
# Out:
#        FECHA  FACTURA  BENEFICIARIO  RFC  CONCEPTO     IMPORTE  \
# 0 2015-01-30     3649           350  107       909   2173840.0
# 1 2015-01-30     3728           350  107       909  12708960.0
# 2 2015-01-30     3972           350  107       909   4346102.4
# 3 2015-01-26      507          1698  194       933   4184000.0
# 4 2015-01-30     1897           922  234      1133     11460.8
#
#   FECHA DEL PAGO POR CADENAS  FUENTE
# 0                 2014-12-04       6
# 1                 2014-12-04       6
# 2                 2014-12-04       6
# 3                 2014-12-04       6
# 4                 2014-12-04       7

# %%
# Utilizar Random forest
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
y = data.pop("IMPORTE")
X = data.copy()

# %%
y.shape
# Out:
# (10313,)

# %%
X.shape
# Out:
# (10313, 7)

# %%
X
# Out:
#            FECHA  FACTURA  BENEFICIARIO  RFC  CONCEPTO  \
# 0     2015-01-30     3649           350  107       909
# 1     2015-01-30     3728           350  107       909
# 2     2015-01-30     3972           350  107       909
# 3     2015-01-26      507          1698  194       933
# 4     2015-01-30     1897           922  234      1133
# ...          ...      ...           ...  ...       ...
# 10308 2015-12-07     5400          1812  308      1484
# 10309 2015-12-07     5400          1817  308      1484
# 10310 2015-12-22     5400          1852  308      1297
# 10311 2015-12-22     5400          1866  308      1297
# 10312 2015-12-29      985          1560  308       367
#
#       FECHA DEL PAGO POR CADENAS  FUENTE
# 0                     2014-12-04       6
# 1                     2014-12-04       6
# 2                     2014-12-04       6
# 3                     2014-12-04       6
# 4                     2014-12-04       7
# ...                          ...     ...
# 10308                 2014-12-04       9
# 10309                 2014-12-04       9
# 10310                 2014-12-04       9
# 10311                 2014-12-04       9
# 10312                 2014-12-04       9
#
# [10313 rows x 7 columns]

# %%
# Dividir los datos en dos grupos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf = RandomForestRegressor(n_estimators=1000, max_depth=4)

# %%
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 clf.fit(X_train, y_train)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_forest.py:363, in BaseForest.fit(self, X, y, sample_weight)
#     360 if issparse(y):
#     361     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 363 X, y = self._validate_data(
#     364     X,
#     365     y,
#     366     multi_output=True,
#     367     accept_sparse="csc",
#     368     dtype=DTYPE,
#     369     force_all_finite=False,
#     370 )
#     371 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     372 # will raise an error if the underlying tree base estimator can't handle missing
#     373 # values. Only the criterion is required to determine if the tree supports
#     374 # missing values.
#     375 estimator = type(self.estimator)(criterion=self.criterion)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1301, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1296         estimator_name = _check_estimator_name(estimator)
#    1297     raise ValueError(
#    1298         f"{estimator_name} requires y to be passed, but the target y is None"
#    1299     )
# -> 1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    1304     accept_large_sparse=accept_large_sparse,
#    1305     dtype=dtype,
#    1306     order=order,
#    1307     copy=copy,
#    1308     force_writeable=force_writeable,
#    1309     force_all_finite=force_all_finite,
#    1310     ensure_2d=ensure_2d,
#    1311     allow_nd=allow_nd,
#    1312     ensure_min_samples=ensure_min_samples,
#    1313     ensure_min_features=ensure_min_features,
#    1314     estimator=estimator,
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1320 check_consistent_length(X, y)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:887, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     883 pandas_requires_conversion = any(
#     884     _pandas_dtype_needs_early_conversion(i) for i in dtypes_orig
#     885 )
#     886 if all(isinstance(dtype_iter, np.dtype) for dtype_iter in dtypes_orig):
# --> 887     dtype_orig = np.result_type(*dtypes_orig)
#     888 elif pandas_requires_conversion and any(d == object for d in dtypes_orig):
#     889     # Force object if any of the dtypes is an object
#     890     dtype_orig = object
#
# DTypePromotionError: The DType <class 'numpy.dtypes.DateTime64DType'> could not be promoted by <class 'numpy.dtypes.Int16DType'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtypes.DateTime64DType'>, <class 'numpy.dtypes.Int16DType'>, <class 'numpy.dtypes.Int16DType'>, <class 'numpy.dtypes.Int16DType'>, <class 'numpy.dtypes.Int16DType'>, <class 'numpy.dtypes.DateTime64DType'>, <class 'numpy.dtypes.Int8DType'>)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, clf.predict(X_test))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 r2_score(y_test, clf.predict(X_test))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_forest.py:1063, in ForestRegressor.predict(self, X)
#    1061 check_is_fitted(self)
#    1062 # Check data
# -> 1063 X = self._validate_X_predict(X)
#    1065 # Assign chunk of trees to jobs
#    1066 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_forest.py:636, in BaseForest._validate_X_predict(self, X)
#     633 """
#     634 Validate X whenever one tries to predict, apply, predict_proba."""
#     635 check_is_fitted(self)
# --> 636 if self.estimators_[0]._support_missing_values(X):
#     637     force_all_finite = "allow-nan"
#     638 else:
#
# AttributeError: 'RandomForestRegressor' object has no attribute 'estimators_'

# %% [markdown]
# ## Modelo no supervisado o de clustering

# %%
#import warnings
#warnings.filterwarnings("ignore", category=UserWarning, modules="sklearn")
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
compras_df_c = df_2015.copy()

# %%
compras_df_c_grupo = compras_df_c.groupby("BENEFICIARIO").agg({"RFC": lambda x: x.nunique(), "IMPORTE":"sum", "FACTURA": lambda x:x.nunique()})

# %%
compras_df_cluster = compras_df_c_grupo.reset_index()
compras_df_cluster
# Out:
#                                            BENEFICIARIO  RFC     IMPORTE  \
# 0              NEUROSERVICES COMMUNICATIONS, SA. DE CV.    1   335440.00
# 1     ABA SEGUROS, SA. DE CV.                       ...    1  4015284.55
# 2                               ABA SEGUROS,S.A DE C.V.    1  6118998.84
# 3                          ABARCA LAYVA CESAR FRANCISCO    1     4299.98
# 4                                   ABDO MOGAS FERNANDO    1     2400.00
# ...                                                 ...  ...         ...
# 1877  ZUBEX INDUSTRIAL,S.A. DE C.V.                 ...    1    72584.40
# 1878                               ZUÑIGA CORREA ARTURO    1     1718.89
# 1879                           ZUÑIGA LEIJA JUAN MARTIN    1   205071.65
# 1880                               ZUÑIGA ROCHA GERARDO    1      935.00
# 1881          iNFRAESTRUCTURA INTEGRAL 2000, SA. DE CV.    1   650999.89
#
#       FACTURA
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 1877        1
# 1878        1
# 1879        1
# 1880        1
# 1881        1
#
# [1882 rows x 4 columns]

# %%
compras_df_c_grupo_f = compras_df_c_grupo.reset_index().drop(["BENEFICIARIO"], axis=1)

# %%
normalizado_compras_df = (compras_df_c_grupo_f-compras_df_c_grupo_f.min())/(compras_df_c_grupo_f.max()-compras_df_c_grupo_f.min())
normalizado_compras_df
# Out:
#       RFC   IMPORTE  FACTURA
# 0     0.0  0.000576      0.0
# 1     0.0  0.006895      0.0
# 2     0.0  0.010508      0.0
# 3     0.0  0.000007      0.0
# 4     0.0  0.000004      0.0
# ...   ...       ...      ...
# 1877  0.0  0.000124      0.0
# 1878  0.0  0.000003      0.0
# 1879  0.0  0.000352      0.0
# 1880  0.0  0.000001      0.0
# 1881  0.0  0.001118      0.0
#
# [1882 rows x 3 columns]

# %%
wcss = []

# %%
import os
os.environ['LOKY_MAX_CPU_COUNT'] = '4'

# %%
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, max_iter=300)
    kmeans.fit(normalizado_compras_df)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1, 11), wcss)
plt.title("Codo de Jambú")
plt.xlabel("Número de cluster")
plt.ylabel("WCSS")
plt.show()

# %%
clustering = kmeans = KMeans(n_clusters=3, max_iter=300)
kmeans.fit(normalizado_compras_df)
# Out:
# KMeans(n_clusters=3)

# %%
compras_df_cluster["KMeans_Cluster"] = clustering.labels_

# %%
compras_df_cluster["KMeans_Cluster"].value_counts()
# Out:
# KMeans_Cluster
# 0    1844
# 1      36
# 2       2
# Name: count, dtype: int64

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca_compras = pca.fit_transform(normalizado_compras_df)

# %%
pca_compras_df = pd.DataFrame(data=pca_compras, columns=["componente_1", "componente_2"])

# %%
pca_nombres_beneficiario = pd.concat([pca_compras_df, compras_df_cluster["KMeans_Cluster"]], axis=1)

# %%
pca_nombres_beneficiario
# Out:
#       componente_1  componente_2  KMeans_Cluster
# 0        -0.006454     -0.002619               0
# 1        -0.005391      0.001276               0
# 2        -0.004783      0.003504               0
# 3        -0.006550     -0.002970               0
# 4        -0.006551     -0.002972               0
# ...            ...           ...             ...
# 1877     -0.006530     -0.002898               0
# 1878     -0.006551     -0.002973               0
# 1879     -0.006492     -0.002758               0
# 1880     -0.006551     -0.002974               0
# 1881     -0.006363     -0.002285               0
#
# [1882 rows x 3 columns]

# %%
plt.figure(figsize=(10,8))

# %%
scatter = plt.scatter(pca_nombres_beneficiario['componente_1'],
                      pca_nombres_beneficiario['componente_2'],
                      c = pca_nombres_beneficiario["KMeans_Cluster"],
                      cmap='viridis',
                      s=100,
                      alpha=0.7)

plt.title("Clusters formados mediante KMeans y PCA")
plt.xlabel("Componente 1")
plt.ylabel("Componente 2")
legend1 = plt.legend(*scatter.legend_elements(), title="Clusters")
plt.gca().add_artist(legend1)
